# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/multiple-linear-regression-dataset/multiple_linear_regression_dataset.csv

# %%
df = pd.read_csv("/kaggle/input/multiple-linear-regression-dataset/multiple_linear_regression_dataset.csv")

# %%
df
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
df.sample()
# Out:
#    age  experience  income
# 9   39           8   45150

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         20 non-null     int64
#  1   experience  20 non-null     int64
#  2   income      20 non-null     int64
# dtypes: int64(3)
# memory usage: 608.0 bytes

# %%
df.describe()
# Out:
#              age  experience        income
# count  20.000000   20.000000     20.000000
# mean   39.650000    6.200000  40735.500000
# std    10.027725    4.124382   8439.797625
# min    23.000000    1.000000  27840.000000
# 25%    31.500000    3.750000  35452.500000
# 50%    40.000000    5.000000  40190.000000
# 75%    47.000000    9.000000  45390.000000
# max    58.000000   17.000000  63600.000000

# %%
df.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.scatter_3d(df, x='age', y='experience', z='income')

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,0:2]
y= df.iloc[:,-1]

# %%
X
# Out:
#     age  experience
# 0    25           1
# 1    30           3
# 2    47           2
# 3    32           5
# 4    43          10
# 5    51           7
# 6    28           5
# 7    33           4
# 8    37           5
# 9    39           8
# 10   29           1
# 11   47           9
# 12   54           5
# 13   51           4
# 14   44          12
# 15   41           6
# 16   58          17
# 17   23           1
# 18   44           9
# 19   37          10

# %%
y
# Out:
# 0     30450
# 1     35670
# 2     31580
# 3     40130
# 4     47830
# 5     41630
# 6     41340
# 7     37650
# 8     40250
# 9     45150
# 10    27840
# 11    46110
# 12    36720
# 13    34800
# 14    51300
# 15    38900
# 16    63600
# 17    30870
# 18    44190
# 19    48700
# Name: income, dtype: int64

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2 , random_state=3)

# %%
X_train
# Out:
#     age  experience
# 4    43          10
# 16   58          17
# 6    28           5
# 7    33           4
# 15   41           6
# 12   54           5
# 9    39           8
# 11   47           9
# 19   37          10
# 18   44           9
# 13   51           4
# 5    51           7
# 0    25           1
# 8    37           5
# 3    32           5
# 10   29           1

# %%
y_train
# Out:
# 4     47830
# 16    63600
# 6     41340
# 7     37650
# 15    38900
# 12    36720
# 9     45150
# 11    46110
# 19    48700
# 18    44190
# 13    34800
# 5     41630
# 0     30450
# 8     40250
# 3     40130
# 10    27840
# Name: income, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression

# %%
print(type(X_train), type(y_train))
print(X_train.shape, y_train.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'>
# (16, 2) (16,)

# %%
from sklearn.model_selection import train_test_split

# Assuming X and y are defined correctly
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# Check their shapes
print(X_train.shape, y_train.shape)
# Out:
# (16, 2) (16,)

# %%
from sklearn.linear_model import LinearRegression

# Initialize the model
lr = LinearRegression()

# Fit the model to the training data
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred =lr.predict(X_test)

# %%
mae=print("MAE",mean_absolute_error(y_test,y_pred))
mse=print("MSE",mean_squared_error(y_test,y_pred))
r2=print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 1071.5766954370147
# MSE 1901454.8827072307
# R2 score 0.9579002513351036

# %%
age = np.linspace(df['age'].min(), df['age'].max(), 20)
experience = np.linspace(df['experience'].min(), df['experience'].max(), 20)
ageGrid, experienceGrid = np.meshgrid(age, experience)

# %%
final = np.vstack([ageGrid.ravel(), experienceGrid.ravel()]).T

# %%
z = lr.predict(final).reshape(ageGrid.shape)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names

# %%
fig = go.Figure()

# %%
scatter = go.Scatter3d(x=df['age'], y=df['experience'], z=df['income'], 
                       mode='markers', marker=dict(size=5, color='blue', opacity=0.8), name='Actual Data')
fig.add_trace(scatter)
# Out:
# <div>                            <div id="02c137d0-208c-4838-a607-9cff48b1954b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02c137d0-208c-4838-a607-9cff48b1954b")) {                    Plotly.newPlot(                        "02c137d0-208c-4838-a607-9cff48b1954b",                        [{"marker":{"color":"blue","opacity":0.8,"size":5},"mode":"markers","name":"Actual Data","x":[25,30,47,32,43,51,28,33,37,39,29,47,54,51,44,41,58,23,44,37],"y":[1,3,2,5,10,7,5,4,5,8,1,9,5,4,12,6,17,1,9,10],"z":[30450,35670,31580,40130,47830,41630,41340,37650,40250,45150,27840,46110,36720,34800,51300,38900,63600,30870,44190,48700],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outline
# ...

# %%
surface = go.Surface(x=ageGrid, y=experienceGrid, z=z, opacity=0.5, colorscale='Viridis', name='Predicted Surface')
fig.add_trace(surface)
# Out:
# <div>                            <div id="882698cb-8d0e-402c-a406-89685e7ce92d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("882698cb-8d0e-402c-a406-89685e7ce92d")) {                    Plotly.newPlot(                        "882698cb-8d0e-402c-a406-89685e7ce92d",                        [{"marker":{"color":"blue","opacity":0.8,"size":5},"mode":"markers","name":"Actual Data","x":[25,30,47,32,43,51,28,33,37,39,29,47,54,51,44,41,58,23,44,37],"y":[1,3,2,5,10,7,5,4,5,8,1,9,5,4,12,6,17,1,9,10],"z":[30450,35670,31580,40130,47830,41630,41340,37650,40250,45150,27840,46110,36720,34800,51300,38900,63600,30870,44190,48700],"type":"scatter3d"},{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31
# ...

# %%
fig.update_layout(
    updatemenus=[dict(type="buttons", showactive=False,
                      buttons=[dict(label="Play",
                                    method="animate",
                                    args=[None, dict(frame=dict(duration=100, redraw=True), fromcurrent=True)])])])

# Show the plot
fig.show()
# Out:
# <div>                            <div id="c680d753-ea7d-470d-80d3-3e87a9273b37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c680d753-ea7d-470d-80d3-3e87a9273b37")) {                    Plotly.newPlot(                        "c680d753-ea7d-470d-80d3-3e87a9273b37",                        [{"marker":{"color":"blue","opacity":0.8,"size":5},"mode":"markers","name":"Actual Data","x":[25,30,47,32,43,51,28,33,37,39,29,47,54,51,44,41,58,23,44,37],"y":[1,3,2,5,10,7,5,4,5,8,1,9,5,4,12,6,17,1,9,10],"z":[30450,35670,31580,40130,47830,41630,41340,37650,40250,45150,27840,46110,36720,34800,51300,38900,63600,30870,44190,48700],"type":"scatter3d"},{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31
# ...

# %%
lr.coef_
# Out:
# array([-102.88197553, 2191.86022152])

# %%
lr.intercept_
# Out:
# 31439.552295349127
